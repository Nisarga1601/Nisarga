# %%
import pandas as pd
meteorites = pd.read_csv('/content/Meteorite_Landings.csv',)
meteorites
# Out:
#                         name     id nametype               recclass  mass (g)  \
# 0                     Aachen      1    Valid                     L5      21.0
# 1                     Aarhus      2    Valid                     H6     720.0
# 2                       Abee      6    Valid                    EH4  107000.0
# 3                   Acapulco     10    Valid            Acapulcoite    1914.0
# 4                    Achiras    370    Valid                     L6     780.0
# ...                      ...    ...      ...                    ...       ...
# 30404  Northwest Africa 7319  55621    Valid        L5-melt breccia    6414.0
# 30405   Northwest Africa 732  17814    Valid                     H5     580.0
# 30406  Northwest Africa 7320  55622    Valid  Martian (shergottite)      52.0
# 30407  Northwest Africa 7321  55623    Valid            Acapulcoite     109.0
# 30408  Northwest Africa 7322  55624    Valid                     H4     109.0
#
#         fall                    year    reclat    reclong  \
# 0       Fell  01/01/1880 12:00:00 AM  50.77500    6.08333
# 1       Fell  01/01/1951 12:00:00 AM  56.18333   10.23333
# 2       Fell  01/01/1952 12:00:00 AM  54.21667 -113.00000
# 3       Fell  01/01/1976 12:00:00 AM  16.88333  -99.90000
# 4       Fell  01/01/1902 12:00:00 AM -33.16667  -64.95000
# ...      ...                     ...       ...        ...
# 30404  Found  01/01/2012 12:00:00 AM   0.00000    0.00000
# 30405  Found  01/01/1999 12:00:00 AM  30.55000   -4.96667
# 30406  Found  01/01/2011 12:00:00 AM   0.00000    0.00000
# 30407  Found  01/01/2012 12:00:00 AM   0.00000    0.00000
# 30408  Found  01/01/2012 12:00:00 AM   0.00000        NaN
#
#                 GeoLocation
# 0         (50.775, 6.08333)
# 1      (56.18333, 10.23333)
# 2        (54.21667, -113.0)
# 3         (16.88333, -99.9)
# 4       (-33.16667, -64.95)
# ...                     ...
# 30404            (0.0, 0.0)
# 30405     (30.55, -4.96667)
# 30406            (0.0, 0.0)
# 30407            (0.0, 0.0)
# 30408                   NaN
#
# [30409 rows x 10 columns]

# %%
meteorites.name
# Out:
# 0                       Aachen
# 1                       Aarhus
# 2                         Abee
# 3                     Acapulco
# 4                      Achiras
#                  ...
# 30404    Northwest Africa 7319
# 30405     Northwest Africa 732
# 30406    Northwest Africa 7320
# 30407    Northwest Africa 7321
# 30408    Northwest Africa 7322
# Name: name, Length: 30409, dtype: object

# %%
meteorites.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
meteorites.index
# Out:
# RangeIndex(start=0, stop=30409, step=1)

# %%
import requests

response = requests.get(
    'http://data.nasa.gov/resource/gh4g-9sfh.json',
    params={'$limit':50_000}
)

if response.ok:
   payload = response.json()
else:
   print(f'Request was not successful and returned code: {response.status_code}')
   payload = None

# %%
import pandas as pd

df = pd.DataFrame(payload)
df.head(3)
# Out:
#      name id nametype recclass    mass  fall                     year  \
# 0  Aachen  1    Valid       L5      21  Fell  1880-01-01T00:00:00.000
# 1  Aarhus  2    Valid       H6     720  Fell  1951-01-01T00:00:00.000
# 2    Abee  6    Valid      EH4  107000  Fell  1952-01-01T00:00:00.000
#
#       reclat      reclong                                        geolocation  \
# 0  50.775000     6.083330     {'latitude': '50.775', 'longitude': '6.08333'}
# 1  56.183330    10.233330  {'latitude': '56.18333', 'longitude': '10.23333'}
# 2  54.216670  -113.000000    {'latitude': '54.21667', 'longitude': '-113.0'}
#
#   :@computed_region_cbhk_fwbd :@computed_region_nnqa_25f4
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN

# %%
meteorites.shape
# Out:
# (30409, 10)

# %%
meteorites.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
meteorites.dtypes
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass (g)       float64
# fall            object
# year            object
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %%
meteorites.head()
# Out:
#        name   id nametype     recclass  mass (g)  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                      year    reclat    reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000    (54.21667, -113.0)
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000     (16.88333, -99.9)
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000   (-33.16667, -64.95)

# %%
meteorites.tail()
# Out:
#                         name     id nametype               recclass  mass (g)  \
# 30404  Northwest Africa 7319  55621    Valid        L5-melt breccia    6414.0
# 30405   Northwest Africa 732  17814    Valid                     H5     580.0
# 30406  Northwest Africa 7320  55622    Valid  Martian (shergottite)      52.0
# 30407  Northwest Africa 7321  55623    Valid            Acapulcoite     109.0
# 30408  Northwest Africa 7322  55624    Valid                     H4     109.0
#
#         fall                    year  reclat  reclong        GeoLocation
# 30404  Found  01/01/2012 12:00:00 AM    0.00  0.00000         (0.0, 0.0)
# 30405  Found  01/01/1999 12:00:00 AM   30.55 -4.96667  (30.55, -4.96667)
# 30406  Found  01/01/2011 12:00:00 AM    0.00  0.00000         (0.0, 0.0)
# 30407  Found  01/01/2012 12:00:00 AM    0.00  0.00000         (0.0, 0.0)
# 30408  Found  01/01/2012 12:00:00 AM    0.00      NaN                NaN

# %%
meteorites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30409 entries, 0 to 30408
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         30409 non-null  object
#  1   id           30409 non-null  int64
#  2   nametype     30409 non-null  object
#  3   recclass     30409 non-null  object
#  4   mass (g)     30335 non-null  float64
#  5   fall         30409 non-null  object
#  6   year         30138 non-null  object
#  7   reclat       24360 non-null  float64
#  8   reclong      24359 non-null  float64
#  9   GeoLocation  24359 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.3+ MB

# %%
meteorites.name
# Out:
# 0                       Aachen
# 1                       Aarhus
# 2                         Abee
# 3                     Acapulco
# 4                      Achiras
#                  ...
# 30404    Northwest Africa 7319
# 30405     Northwest Africa 732
# 30406    Northwest Africa 7320
# 30407    Northwest Africa 7321
# 30408    Northwest Africa 7322
# Name: name, Length: 30409, dtype: object

# %%
meteorites[['name', 'mass (g)']]
# Out:
#                         name  mass (g)
# 0                     Aachen      21.0
# 1                     Aarhus     720.0
# 2                       Abee  107000.0
# 3                   Acapulco    1914.0
# 4                    Achiras     780.0
# ...                      ...       ...
# 30404  Northwest Africa 7319    6414.0
# 30405   Northwest Africa 732     580.0
# 30406  Northwest Africa 7320      52.0
# 30407  Northwest Africa 7321     109.0
# 30408  Northwest Africa 7322     109.0
#
# [30409 rows x 2 columns]

# %%
meteorites[100:104]
# Out:
#               name     id nametype       recclass  mass (g)  fall  \
# 100         Benton   5026    Valid            LL6    2840.0  Fell
# 101         Berduc  48975    Valid             L6     270.0  Fell
# 102         Béréba   5028    Valid  Eucrite-mmict   18000.0  Fell
# 103  Berlanguillas   5029    Valid             L6    1440.0  Fell
#
#                        year    reclat   reclong          GeoLocation
# 100  01/01/1949 12:00:00 AM  45.95000 -67.55000      (45.95, -67.55)
# 101  01/01/2008 12:00:00 AM -31.91000 -58.32833  (-31.91, -58.32833)
# 102  01/01/1924 12:00:00 AM  11.65000  -3.65000       (11.65, -3.65)
# 103  01/01/1811 12:00:00 AM  41.68333  -3.80000     (41.68333, -3.8)

# %%
meteorites.iloc[100:104, [0,3,4,6]]
# Out:
#               name       recclass  mass (g)                    year
# 100         Benton            LL6    2840.0  01/01/1949 12:00:00 AM
# 101         Berduc             L6     270.0  01/01/2008 12:00:00 AM
# 102         Béréba  Eucrite-mmict   18000.0  01/01/1924 12:00:00 AM
# 103  Berlanguillas             L6    1440.0  01/01/1811 12:00:00 AM

# %%
meteorites.loc[100:104, 'mass (g)':'year']
# Out:
#      mass (g)  fall                    year
# 100    2840.0  Fell  01/01/1949 12:00:00 AM
# 101     270.0  Fell  01/01/2008 12:00:00 AM
# 102   18000.0  Fell  01/01/1924 12:00:00 AM
# 103    1440.0  Fell  01/01/1811 12:00:00 AM
# 104     960.0  Fell  01/01/2004 12:00:00 AM

# %% [markdown]
# (meteorites['mass (g)'] > 50) & (meteorites.fall == 'Found')

# %%
meteorites[(meteorites['mass (g)']>1e6) & (meteorites.fall == 'Fell')]
# Out:
#               name     id nametype    recclass    mass (g)  fall  \
# 29         Allende   2278    Valid         CV3   2000000.0  Fell
# 419          Jilin  12171    Valid          H5   4000000.0  Fell
# 506  Kunya-Urgench  12379    Valid          H5   1100000.0  Fell
# 707  Norton County  17922    Valid     Aubrite   1100000.0  Fell
# 920   Sikhote-Alin  23593    Valid  Iron, IIAB  23000000.0  Fell
#
#                        year    reclat    reclong             GeoLocation
# 29   01/01/1969 12:00:00 AM  26.96667 -105.31667  (26.96667, -105.31667)
# 419  01/01/1976 12:00:00 AM  44.05000  126.16667      (44.05, 126.16667)
# 506  01/01/1998 12:00:00 AM  42.25000   59.20000           (42.25, 59.2)
# 707  01/01/1948 12:00:00 AM  39.68333  -99.86667   (39.68333, -99.86667)
# 920  01/01/1947 12:00:00 AM  46.16000  134.65333      (46.16, 134.65333)

# %%
meteorites.query("`mass (g)` > 1e6 and fall == 'Fell'")
# Out:
#               name     id nametype    recclass    mass (g)  fall  \
# 29         Allende   2278    Valid         CV3   2000000.0  Fell
# 419          Jilin  12171    Valid          H5   4000000.0  Fell
# 506  Kunya-Urgench  12379    Valid          H5   1100000.0  Fell
# 707  Norton County  17922    Valid     Aubrite   1100000.0  Fell
# 920   Sikhote-Alin  23593    Valid  Iron, IIAB  23000000.0  Fell
#
#                        year    reclat    reclong             GeoLocation
# 29   01/01/1969 12:00:00 AM  26.96667 -105.31667  (26.96667, -105.31667)
# 419  01/01/1976 12:00:00 AM  44.05000  126.16667      (44.05, 126.16667)
# 506  01/01/1998 12:00:00 AM  42.25000   59.20000           (42.25, 59.2)
# 707  01/01/1948 12:00:00 AM  39.68333  -99.86667   (39.68333, -99.86667)
# 920  01/01/1947 12:00:00 AM  46.16000  134.65333      (46.16, 134.65333)

# %%
meteorites.fall.value_counts(normalize=True)
# Out:
# Found    0.963596
# Fell     0.036404
# Name: fall, dtype: float64

# %%
meteorites.fall.value_counts(normalize=False)
# Out:
# Found    29302
# Fell      1107
# Name: fall, dtype: int64

# %%
meteorites['mass (g)'].mean()
# Out:
# 17017.69984153618

# %%
meteorites.fall.value_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-4c6506d42f12> in <cell line: 1>()
# ----> 1 meteorites.fall.value_
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value_'
